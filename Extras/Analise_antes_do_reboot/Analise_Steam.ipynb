# %% [markdown]
# # Código das Medidas de Centralidade
#
# ## Médias e Medianas relativas as vendas dos 1000 primeiros jogos mais vendidos

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')

#1000 primeiros pra análise ficar congruente
df = df.head(1000)

# Desvio Padrao das vendas na América Do Norte, Europa, Japão, outros e Global
std_na = df['NA_Sales'].std()
std_eu = df['EU_Sales'].std()
std_jp = df['JP_Sales'].std()
std_other = df['Other_Sales'].std()
std_global = df['Global_Sales'].std()

# Medianas das vendas na América Do Norte, Europa, Japão, outros e Global
median_na = df['NA_Sales'].median()
median_eu = df['EU_Sales'].median()
median_jp = df['JP_Sales'].median()
median_other = df['Other_Sales'].median()
median_global = df['Global_Sales'].median()

# Medias das vendas na América Do Norte, Europa, Japão, outros e Global
mean_na = df['NA_Sales'].mean()
mean_eu = df['EU_Sales'].mean()
mean_jp = df['JP_Sales'].mean()
mean_other = df['Other_Sales'].mean()
mean_global = df['Global_Sales'].mean()


print(f"Desvio Padrão - NA: {std_na}, EU: {std_eu}, JP: {std_jp}, "
      f"Other: {std_other}, Global: {std_global} \n")

print(f"Mediana - NA: {median_na}, EU: {median_eu}, JP: {median_jp}, "
      f"Other: {median_other}, Global: {median_global} \n")

print(f"Média - NA: {mean_na}, EU: {mean_eu}, JP: {mean_jp}, "
      f"Other: {mean_other}, Global: {mean_global} \n")
# Out:
# Desvio Padrão - NA: 2.616129164185841, EU: 1.6234816298937915, JP: 1.0381556524716122, Other: 0.643863504644123, Global: 4.8146288515916345
#
# Mediana - NA: 1.5, EU: 0.9, JP: 0.07500000000000001, Other: 0.24, Global: 2.89
#
# Média - NA: 2.0790900000000003, EU: 1.2586999999999997, JP: 0.5507799999999999, Other: 0.40074, Global: 4.28918

# %% [markdown]
# ## Modas

# %%
contagem_por_ano = df.groupby('Year').size()

ano_com_mais_jogos = contagem_por_ano.idxmax()
quantidade_jogos_ano = contagem_por_ano.max()

print(f"O ano com o maior número de jogos é {ano_com_mais_jogos} com {quantidade_jogos_ano} jogos.")

contagem_por_console = df.groupby('Platform').size()

console_com_mais_jogos = contagem_por_console.idxmax()
quantidade_jogos_console = contagem_por_console.max()

print(f"O console com o maior número de jogos é {console_com_mais_jogos} com {quantidade_jogos_console} jogos.")

contagem_por_genero = df.groupby('Genre').size()

genero_com_mais_jogos = contagem_por_genero.idxmax()
quantidade_jogos_genero = contagem_por_genero.max()

print(f"O genero com o maior número de jogos é {genero_com_mais_jogos} com {quantidade_jogos_genero} jogos.")

contagem_por_empresa = df.groupby('Publisher').size()

empresa_com_mais_jogos = contagem_por_empresa.idxmax()
quantidade_jogos_empresa = contagem_por_empresa.max()

print(f"A empresa com o maior número de jogos é {empresa_com_mais_jogos} com {quantidade_jogos_empresa} jogos.")
# Out:
# O ano com o maior número de jogos é 2007.0 com 69 jogos.
# O console com o maior número de jogos é PS2 com 164 jogos.
# O genero com o maior número de jogos é Action com 205 jogos.
# A empresa com o maior número de jogos é Nintendo com 229 jogos.

# %% [markdown]
# ## BoxPlot Vendas globais e gráficos de medidas de centralidade e dispersão

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000)

df['Global_Sales'].plot(kind='box')
plt.title('Global Sales')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregar dados
df = pd.read_csv('vgsales.csv')

# Limitando dataframe
df = df.head(100)

# Cálculo das estatísticas
stats = {
    'Desvio Padrão': [df['NA_Sales'].std(), df['EU_Sales'].std(), df['JP_Sales'].std(), df['Other_Sales'].std(), df['Global_Sales'].std()],
    'Mediana': [df['NA_Sales'].median(), df['EU_Sales'].median(), df['JP_Sales'].median(), df['Other_Sales'].median(), df['Global_Sales'].median()],
    'Média': [df['NA_Sales'].mean(), df['EU_Sales'].mean(), df['JP_Sales'].mean(), df['Other_Sales'].mean(), df['Global_Sales'].mean()]
}

# Criar DataFrame para os gráficos
stats_df = pd.DataFrame(stats, index=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'])

# Plotar
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Gráfico do Desvio Padrão
axs[0].bar(stats_df.index, stats_df['Desvio Padrão'], color='skyblue')
axs[0].set_title('Desvio Padrão das Vendas')
axs[0].set_ylabel('Desvio Padrão')

# Gráfico da Mediana
axs[1].bar(stats_df.index, stats_df['Mediana'], color='lightgreen')
axs[1].set_title('Mediana das Vendas')
axs[1].set_ylabel('Mediana')

# Gráfico da Média
axs[2].bar(stats_df.index, stats_df['Média'], color='salmon')
axs[2].set_title('Média das Vendas')
axs[2].set_ylabel('Média')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gráfico de Dispersão
# ### Comparando as vendas de cada pais com as vendas globais, a fim de ver como cada país impacta no cenário global

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000)

plt.scatter(df['NA_Sales'], df['Global_Sales'], label='NA vs Global', color='blue') 
plt.xlabel('Vendas na América do Norte (NA_Sales)')
plt.ylabel('Vendas Globais (Global_Sales)')
plt.title('Vendas na América do Norte vs Vendas Globais')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000)

plt.scatter(df['EU_Sales'], df['Global_Sales'], label='EU vs Global', color='black') 
plt.xlabel('Vendas na Europa (EU_Sales)')
plt.ylabel('Vendas Globais (Global_Sales)')
plt.title('Vendas na Europa vs Vendas Globais')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000)

plt.scatter(df['JP_Sales'], df['Global_Sales'], label='Jp vs Global', color='red') 
plt.xlabel('Vendas no Japão (JP_Sales)')
plt.ylabel('Vendas Globais (Global_Sales)')
plt.title('Vendas no Japão vs Vendas Globais')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000)

plt.scatter(df['Other_Sales'], df['Global_Sales'], label='Other vs Global', color='green') 
plt.xlabel('Vendas em outras regiões (Other_Sales)')
plt.ylabel('Vendas Globais (Global_Sales)')
plt.title('Vendas em outras regiões vs Vendas Globais')
plt.show()

# %% [markdown]
# ## Gráfico de Histograma
# ### Para entender a frequência de valores dentro de intervalos específicos.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000)

plt.hist(df['Global_Sales'], bins=20, color='blue', edgecolor='black')
plt.title('Distribuição de Vendas Globais')
plt.xlabel('Vendas Globais (em milhões)')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ## Gráfico de Barra
# ### Para comparar cada plataforma e suas vendas

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')
df = df.head(1000) 

# Agrupar vendas globais por plataforma
vendas_por_plataforma = df.groupby('Platform')['Global_Sales'].sum()

# Criar o gráfico de barras
plt.bar(vendas_por_plataforma.index, vendas_por_plataforma.values, color='black')
plt.title('Vendas Globais por Plataforma')
plt.xlabel('Plataformas')
plt.ylabel('Vendas Globais (em milhões)')
plt.xticks(rotation=90)  # Rotaciona os rótulos no eixo X
plt.show()
